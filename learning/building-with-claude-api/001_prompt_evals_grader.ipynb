# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6.333333333333333

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# Extract S3 Bucket Names from CloudFormation Template\n\nI'd be happy to help extract S3 bucket names from an AWS CloudFormation template. However, I don't see the template in your message.\n\nPlease provide the CloudFormation template (in JSON or YAML format), and I'll extract all S3 bucket names for you.\n\n## Expected Input Formats:\n\n**JSON Example:**\n```json\n{\n  \"Resources\": {\n    \"MyBucket\": {\n      \"Type\": \"AWS::S3::Bucket\",\n      \"Properties\": {\n        \"BucketName\": \"my-bucket-name\"\n      }\n    }\n  }\n}\n```\n\n**YAML Example:**\n```yaml\nResources:\n  MyBucket:\n    Type: AWS::S3::Bucket\n    Properties:\n      BucketName: my-bucket-name\n```\n\n## What I'll Do:\n\nOnce you provide the template, I will:\n1. \u2705 Identify all `AWS::S3::Bucket` resources\n2. \u2705 Extract explicit bucket names (from `BucketName` property)\n3. \u2705 Identify auto-generated bucket names (when `BucketName` is not specified)\n4. \u2705 List all S3 bucket references in Outputs section\n5. \u2705 Return a clean list of all bucket names\n\n**Please paste your CloudFormation template below, and I'll extract the bucket names!**",
#     "test_case": {
#       "task": "Extract all S3 bucket names from AWS CloudFormation template output",
#       "format": "regex"
#     },
#     "score": 3,
#     "reasoning": "This response reads as a conversational prompt requesting user input rather than a working solution. While it demonstrates understanding of CloudFormation structure and what needs to be extracted, it fails to deliver the core requirement: actual code to extract bucket names. A proper solution should include a working script (Python, Bash, or similar) that parses CloudFormation templates and outputs bucket names, possibly with sample execution. The approach is pedagogically sound but technically incomplete."
#   },
#   {
#     "output": "# S3 Read-Only Access Policy\n\nHere's a JSON policy document that allows read-only access to a specific S3 bucket:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"S3ReadOnlyAccess\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\",\n        \"s3:GetObjectAcl\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-bucket-name/*\"\n    },\n    {\n      \"Sid\": \"S3ListBucketAccess\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketVersioning\",\n        \"s3:ListBucketVersions\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-bucket-name\"\n    }\n  ]\n}\n```\n\n## Key Components\n\n| Component | Description |\n|-----------|-------------|\n| **GetObject** | Read object contents |\n| **GetObjectVersion** | Read specific object versions |\n| **GetObjectAcl** | View object permissions |\n| **ListBucket** | List bucket contents |\n| **GetBucketVersioning** | Check versioning status |\n| **ListBucketVersions** | List all object versions |\n\n## Usage Instructions\n\n1. **Replace `my-bucket-name`** with your actual S3 bucket name\n2. Attach this policy to an IAM user, role, or group\n3. The policy grants read-only permissions without allowing modifications\n\n## Minimal Policy (Basic Read-Only)\n\nIf you only need basic read access:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:ListBucket\"\n      ],\n      \"Resource\": [\n        \"arn:aws:s3:::my-bucket-name\",\n        \"arn:aws:s3:::my-bucket-name/*\"\n      ]\n    }\n  ]\n}\n```\n\nThis ensures users can only **read** objects and cannot **write, delete, or modify** any data in the bucket.",
#     "test_case": {
#       "task": "Create a JSON policy document that allows read-only access to a specific S3 bucket",
#       "format": "json"
#     },
#     "score": 7,
#     "reasoning": "The solution correctly addresses the core task by providing valid read-only S3 access policies with proper ARN syntax and resource separation. The dual approach (comprehensive + minimal) is helpful. However, it includes some unnecessary permissions like GetObjectAcl and lacks discussion of security best practices like least-privilege principle or explicit deny statements. The policies are functional and would work as intended, but could be more tightly scoped."
#   },
#   {
#     "output": "# AWS Access Key Format Validator\n\nHere's a Python function that validates AWS access key format:\n\n```python\nimport re\n\ndef validate_aws_access_key(access_key: str) -> bool:\n    \"\"\"\n    Validates AWS access key format.\n    \n    AWS Access Keys follow the pattern:\n    - Start with \"AKIA\" (4 characters)\n    - Followed by exactly 16 alphanumeric characters (A-Z, 0-9)\n    \n    Args:\n        access_key (str): The AWS access key to validate\n        \n    Returns:\n        bool: True if valid, False otherwise\n        \n    Example:\n        >>> validate_aws_access_key(\"AKIAIOSFODNN7EXAMPLE\")\n        True\n        >>> validate_aws_access_key(\"AKIA1234567890ABCDEF\")\n        True\n        >>> validate_aws_access_key(\"AKIAIOSFODNN7EXAMPL\")  # Too short\n        False\n        >>> validate_aws_access_key(\"BKIAIOSFODNN7EXAMPLE\")  # Wrong prefix\n        False\n    \"\"\"\n    pattern = r'^AKIA[A-Z0-9]{16}$'\n    return bool(re.match(pattern, access_key))\n\n\n# Alternative implementation without regex\ndef validate_aws_access_key_no_regex(access_key: str) -> bool:\n    \"\"\"\n    Validates AWS access key format without using regex.\n    \n    Args:\n        access_key (str): The AWS access key to validate\n        \n    Returns:\n        bool: True if valid, False otherwise\n    \"\"\"\n    # Check length (4 + 16 = 20 characters)\n    if len(access_key) != 20:\n        return False\n    \n    # Check prefix\n    if not access_key.startswith('AKIA'):\n        return False\n    \n    # Check remaining 16 characters are alphanumeric\n    return access_key[4:].isalnum() and access_key[4:].isupper()\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        (\"AKIAIOSFODNN7EXAMPLE\", True),      # Valid\n        (\"AKIA1234567890ABCDEF\", True),      # Valid\n        (\"AKIAIOSFODNN7EXAMPL\", False),      # Too short (19 chars)\n        (\"AKIAIOSFODNN7EXAMPLEX\", False),    # Too long (21 chars)\n        (\"BKIAIOSFODNN7EXAMPLE\", False),     # Wrong prefix\n        (\"akiaiosfodnn7example\", False),     # Lowercase prefix\n        (\"AKIA-IOSFODNN7EXAMPL\", False),     # Contains invalid character (-)\n        (\"AKIA_IOSFODNN7EXAMPL\", False),     # Contains invalid character (_)\n        (\"AKIA123456789ABCDEF1\", True),      # Valid with numbers\n        (\"\", False),                          # Empty string\n        (\"AKIA\", False),                      # Too short\n    ]\n    \n    print(\"Testing validate_aws_access_key (regex version):\")\n    print(\"-\" * 60)\n    for access_key, expected in test_cases:\n        result = validate_aws_access_key(access_key)\n        status = \"\u2713\" if result == expected else \"\u2717\"\n        print(f\"{status} validate_aws_access_key('{access_key}') = {result} (expected {expected})\")\n    \n    print(\"\\n\\nTesting validate_aws_access_key_no_regex (non-regex version):\")\n    print(\"-\" * 60)\n    for access_key, expected in test_cases:\n        result = validate_aws_access_key_no_regex(access_key)\n        status = \"\u2713\" if result == expected else \"\u2717\"\n        print(f\"{status} validate_aws_access_key_no_regex('{access_key}') = {result} (expected {expected})\")\n```\n\n**Output:**\n```\nTesting validate_aws_access_key (regex version):\n------------------------------------------------------------\n\u2713",
#     "test_case": {
#       "task": "Write a Python function that validates AWS access key format (AKIA followed by 16 alphanumeric characters)",
#       "format": "python"
#     },
#     "score": 6,
#     "reasoning": "The regex-based solution correctly solves the stated requirement with clear documentation and good test coverage. However, the alternative non-regex implementation contains a logical error that breaks its functionality for keys containing numbers. The test output is incomplete (ends mid-execution), suggesting the code may have issues running. Input validation is also missing, which is important for production use. The regex solution alone would score higher, but the buggy alternative and incomplete testing lower the overall assessment."
#   }
# ]
